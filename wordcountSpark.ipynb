# %%
# set up a spark session
from pyspark.sql import SparkSession

# %%
spark = SparkSession \
    .builder \
    .appName("Python Spark SQL basic example") \
    .getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In[12], line 4
#       1 spark = SparkSession \
#       2     .builder \
#       3     .appName("Python Spark SQL basic example") \
# ----> 4     .getOrCreate()
#
# File ~\anaconda3\Lib\site-packages\pyspark\sql\session.py:477, in SparkSession.Builder.getOrCreate(self)
#     475     sparkConf.set(key, value)
#     476 # This SparkContext may be an existing one.
# --> 477 sc = SparkContext.getOrCreate(sparkConf)
#     478 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     479 # by all sessions.
#     480 session = SparkSession(sc, options=self._options)
#
# File ~\anaconda3\Lib\site-packages\pyspark\context.py:512, in SparkContext.getOrCreate(cls, conf)
#     510 with SparkContext._lock:
#     511     if SparkContext._active_spark_context is None:
# ...

# %%
sc = spark.sparkContext
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 sc = spark.sparkContext
#
# NameError: name 'spark' is not defined

# %%
type(sc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 type(sc)
#
# NameError: name 'sc' is not defined

# %%
txt = sc.textFile("constituiton.txt")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 txt = sc.textFile("constituiton.txt")
#
# NameError: name 'sc' is not defined

# %%
txt.count()
txt.take(10)

# %%
import pandas as pd
staffdf = pd.read_csv("staff.csv")

# %%
staff = spark.createDataFrame(staffdf)
staff.createOrReplaceTempView("staff")
spark.sql("SELECT * FROM staff WHERE sales > 100.0")
